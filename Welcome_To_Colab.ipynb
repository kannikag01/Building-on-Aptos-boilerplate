# %% [markdown]
# <a href="https://colab.research.google.com/github/kannikag01/Building-on-Aptos-boilerplate/blob/boilerplate_02/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
